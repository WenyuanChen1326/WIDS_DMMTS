# %% [markdown]
# <h1>Aim 2</h1>
# <h3>WIDS 2024 Challenge ++</h3>
# <h3>BMI 212 - Team DMMTS</h3>

# %%
import lightgbm as lgb
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import roc_auc_score, roc_curve, auc, mean_squared_error, accuracy_score, precision_score, recall_score, confusion_matrix
from sklearn import preprocessing

# %% [markdown]
# <h4> Load the data</h4>

# %%
# Load the CSV dataset
nonimpute_raw_df = pd.read_csv('../Data/train_test_added_climate_data.csv')
impute_raw_df = pd.read_csv('../Data/train_test_added_climate_data_imputed.csv')

# Rename feature columns for better readability
columns_dict = {'bmi': 'patient_bmi',
                   'region': 'patient_region',
                   'division': 'patient_division',
                   'side': 'patient_tumor_side',
                   'quadrant': 'patient_tumor_quadrant',
                   'metastatic_organ': 'patient_metastatic_organ',
                   'cleaned_metastatic_first_treatment': 'patient_metastatic_first_treatment',
                   'cleaned_metastatic_first_treatment_type': 'patient_metastatic_first_treatment_type',
                   'population': 'population_size',
                   'density': 'population_density',
                   'age_median': 'population_age_median',
                   'female': 'population_female_perc',
                   'married': 'population_married_perc',
                   'divorced': 'population_divorced_perc',
                   'never_married': 'population_never_married_perc',
                   'widowed': 'population_widowed_perc',
                   'family_size': 'population_family_size',
                   'family_dual_income': 'population_family_dual_income_perc',
                   'income_individual_median': 'population_income_individual_median',
                   'income_household_median': 'population_income_household_median',
                   'home_ownership': 'population_home_ownership_perc',
                   'home_value': 'population_home_value',
                   'rent_median': 'population_rent_median',
                   'rent_burden': 'population_rent_burden_perc',
                   'education_less_highschool': 'population_education_less_highschool_perc',
                   'education_highschool': 'population_education_highschool_perc',
                   'education_some_college': 'population_education_some_college_perc',
                   'education_bachelors': 'population_education_bachelors_perc',
                   'education_graduate': 'population_education_graduate_perc',
                   'education_college_or_above': 'population_education_college_or_above_perc',
                   'education_stem_degree': 'population_education_stem_degree_perc',
                   'unemployment_rate': 'population_unemployment_rate',
                   'self_employed': 'population_self_employed_perc',
                   'farmer': 'population_farmer_perc',
                   'race_white': 'population_race_white_perc',
                   'race_black': 'population_race_black_perc',
                   'race_asian': 'population_race_asian_perc',
                   'race_native': 'population_race_native_american_perc',
                   'race_pacific': 'population_race_pacific_islander_perc',
                   'race_other': 'population_race_other_perc',
                   'race_multiple': 'population_race_multiple_perc',
                   'hispanic': 'population_hispanic_perc',
                   'disabled': 'population_disabled_perc',
                   'poverty': 'population_poverty_perc',
                   'limited_english': 'population_limited_english_perc',
                   'commute_time': 'population_commute_time',
                   'health_uninsured': 'population_health_uninsured_perc',
                   'veteran': 'population_veteran_perc',
                   'climate_ozone': 'annual_ozone_conc',
                   'climate_pm25': 'annual_fine_particulate_matter_conc',
                   'climate_n02': 'annual_nitrogen_dioxide_conc',
                   'Ozone': 'annual_ozone_conc',
                   'PM25': 'annual_fine_particulate_matter_conc',
                   'N02': 'annual_nitrogen_dioxide_conc'}

nonimpute_raw_df.rename(columns=columns_dict, inplace=True)
impute_raw_df.rename(columns=columns_dict, inplace=True)

# %% [markdown]
# <h4>Select the features to use</h4>

# %%
features = ['patient_race', 'payer_type', 'patient_state', 'patient_age', 'patient_gender', 'patient_bmi',
            'patient_region', 'patient_division', 'patient_tumor_side', 'patient_tumor_quadrant',
            'patient_metastatic_organ', 'patient_metastatic_first_treatment', 'patient_metastatic_first_treatment_type',
            'population_size', 'population_density', 'population_age_median', 'population_female_perc',
            'population_married_perc', 'population_divorced_perc', 'population_never_married_perc',
            'population_widowed_perc', 'population_family_size', 'population_family_dual_income_perc',
            'population_income_individual_median', 'population_income_household_median', 'population_home_ownership_perc',
            'population_home_value', 'population_rent_median', 'population_rent_burden_perc',
            'population_education_less_highschool_perc', 'population_education_highschool_perc',
            'population_education_some_college_perc', 'population_education_bachelors_perc',
            'population_education_graduate_perc', 'population_education_college_or_above_perc',
            'population_education_stem_degree_perc', 'population_unemployment_rate', 'population_self_employed_perc',
            'population_farmer_perc', 'population_race_white_perc', 'population_race_black_perc',
            'population_race_asian_perc', 'population_race_native_american_perc', 'population_race_pacific_islander_perc',
            'population_race_other_perc', 'population_race_multiple_perc', 'population_hispanic_perc',
            'population_disabled_perc', 'population_poverty_perc', 'population_limited_english_perc',
            'population_commute_time', 'population_health_uninsured_perc', 'population_veteran_perc', 'annual_nitrogen_dioxide_conc',
            'annual_fine_particulate_matter_conc', 'annual_ozone_conc']

# Select only rows where allocated_set is train
nonimpute_train_df = nonimpute_raw_df[nonimpute_raw_df['allocated_set'] == 'train']
impute_train_df = impute_raw_df[impute_raw_df['allocated_set'] == 'train']

# Select the features to use
nonimpute_df = nonimpute_train_df[features]
impute_df = impute_train_df[features]

# Extract labels for time to treatment 
labels_df = nonimpute_train_df[['treatment_pd']]

# %% [markdown]
# <h4>Define categorical variables</h4>

# %%
# Convert object features to categorical
for col in nonimpute_df.select_dtypes(include='object').columns:
    nonimpute_df[col] = nonimpute_df[col].astype('category')
    impute_df[col] = impute_df[col].astype('category')

# List of categorical features
categorical_features = list(nonimpute_df.select_dtypes(include='category').columns)
print(categorical_features)
# Out:
# ['patient_race', 'payer_type', 'patient_state', 'patient_gender', 'patient_region', 'patient_division', 'patient_tumor_side', 'patient_tumor_quadrant', 'patient_metastatic_organ', 'patient_metastatic_first_treatment', 'patient_metastatic_first_treatment_type']

# %%
# Note: Significant portion of race data is missing! Double-check that they have been imputed.
impute_df['patient_race'].value_counts(dropna=False)
# Out:
# White       14577
# Black        4713
# Other        3917
# Hispanic     3173
# Asian        1294
# Name: patient_race, dtype: int64

# %% [markdown]
# <h4>Drop low-variance features</h4>

# %%
# Temporarily convert categorical features to distinct numerical codes, keeping missing/NaN values
temp_nonimpute_df = nonimpute_df.copy()
temp_impute_df = impute_df.copy()

for cat_feat in categorical_features:
    temp_nonimpute_df[cat_feat] = temp_nonimpute_df[cat_feat].cat.codes
    temp_impute_df[cat_feat] = temp_impute_df[cat_feat].cat.codes

    temp_nonimpute_df.loc[temp_nonimpute_df[cat_feat] == -1] = np.NaN
    temp_impute_df.loc[temp_impute_df[cat_feat] == -1] = np.NaN

# %%
temp_impute_df.head()
# Out:
#    patient_race  payer_type  patient_state  patient_age  patient_gender  \
# 0           0.0         0.0            4.0         46.0             0.0
# 1           4.0         2.0           35.0         63.0             0.0
# 2           2.0         0.0           44.0         53.0             0.0
# 3           2.0         1.0            4.0         50.0             0.0
# 4           3.0         0.0           34.0         39.0             0.0
#
#    patient_bmi  patient_region  patient_division  patient_tumor_side  \
# 0        27.00             3.0               5.0                 1.0
# 1        27.82             0.0               0.0                 0.0
# 2        27.12             2.0               8.0                 0.0
# 3        26.42             3.0               5.0                 2.0
# 4        18.00             1.0               2.0                 2.0
#
#    patient_tumor_quadrant  ...  population_hispanic_perc  \
# 0                     7.0  ...                 47.726087
# 1                     3.0  ...                  1.182979
# 2                     2.0  ...                 21.064151
# 3                     8.0  ...                 37.948485
# 4                     8.0  ...                 18.960526
#
#    population_disabled_perc  population_poverty_perc  \
# 0                  9.895652                10.515217
# 1                 18.317021                13.546809
# 2                 14.083019                11.943396
# 3                  8.957576                10.109091
# 4                 10.194737                18.642105
#
#    population_limited_english_perc  population_commute_time  \
# 0                        12.745652                32.530435
# 1                         0.146809                31.890909
# 2                         2.549057                32.556250
# 3                         8.057576                30.606061
# 4                        14.173684                42.502632
#
#    population_health_uninsured_perc  population_veteran_perc  \
# 0                          7.263043                 3.810870
# 1                          7.631915                 9.631915
# 2                         16.396226                10.392453
# 3                          7.018182                 4.103030
# 4                          6.392105                 1.755263
#
#    annual_nitrogen_dioxide_conc  annual_fine_particulate_matter_conc  \
# 0                     20.084231                             9.595719
# 1                     12.485563                             8.399666
# 2                     11.522807                             9.361774
# 3                     20.113179                             8.487175
# 4                     27.496367                             7.879795
#
#    annual_ozone_conc
# 0          47.310325
# 1          40.544389
# 2          38.696786
# 3          42.301121
# 4          37.722740
#
# [5 rows x 56 columns]

# %%
from sklearn.feature_selection import VarianceThreshold

# Remove low-var features from temp df (will drop removed cols from original df)
low_var_filter_nonimpute = VarianceThreshold(threshold=(.9 * (1 - .9)))
filtered_features_nonimpute = low_var_filter_nonimpute.fit_transform(temp_nonimpute_df)
filtered_feature_names_nonimpute = low_var_filter_nonimpute.get_feature_names_out(input_features=features)
print("Non-imputed Low-variance features: ", set(features) - set(filtered_feature_names_nonimpute))

low_var_filter_impute = VarianceThreshold(threshold=(.9 * (1 - .9)))
filtered_features_impute = low_var_filter_impute.fit_transform(temp_impute_df)
filtered_feature_names_impute = low_var_filter_impute.get_feature_names_out(input_features=features)
print("Imputed Low-variance features: ", set(features) - set(filtered_feature_names_impute))

nonimpute_df_filtered = nonimpute_df[filtered_feature_names_nonimpute].copy()
impute_df_filtered = impute_df[filtered_feature_names_impute].copy()
# Out:
# Non-imputed Low-variance features:  {'patient_gender', 'population_family_size', 'patient_metastatic_first_treatment_type'}
# Imputed Low-variance features:  {'patient_gender', 'population_family_size', 'patient_metastatic_first_treatment_type'}

# %% [markdown]
# # Categorize label to 30/60/90 day treatment

# %%
# Rename dfs of features and target
X_nonimpute = nonimpute_df_filtered
X_impute = impute_df_filtered
y = labels_df

y_30 = y['treatment_pd'].apply(lambda x: 1 if x <= 30 else 0)

y_60 = y['treatment_pd'].apply(lambda x: 1 if x <= 60 else 0)

y_90 = y['treatment_pd'].apply(lambda x: 1 if x <= 90 else 0)

# %% [markdown]
# # Split into train/test 80/20

# %%
# Split the data into train/test split (80/20) - preserve class counts between splits
X_train_nonimpute_30, X_test_nonimpute_30, y_train_30, y_test_30 = train_test_split(X_nonimpute, y_30, test_size=0.2, random_state=123, stratify=y_30)
X_train_impute_30, X_test_impute_30, y_train_30, y_test_30 = train_test_split(X_impute, y_30, test_size=0.2, random_state=123, stratify=y_30)
print(y_train_30.value_counts())
print(y_test_30.value_counts())

X_train_nonimpute_60, X_test_nonimpute_60, y_train_60, y_test_60 = train_test_split(X_nonimpute, y_60, test_size=0.2, random_state=123, stratify=y_60)
X_train_impute_60, X_test_impute_60, y_train_60, y_test_60 = train_test_split(X_impute, y_60, test_size=0.2, random_state=123, stratify=y_60)
print(y_train_60.value_counts())
print(y_test_60.value_counts())

X_train_nonimpute_90, X_test_nonimpute_90, y_train_90, y_test_90 = train_test_split(X_nonimpute, y_90, test_size=0.2, random_state=123, stratify=y_90)
X_train_impute_90, X_test_impute_90, y_train_90, y_test_90 = train_test_split(X_impute, y_90, test_size=0.2, random_state=123, stratify=y_90)
print(y_train_90.value_counts())
print(y_test_90.value_counts())
# Out:
# 0    17714
# 1     4425
# Name: treatment_pd, dtype: int64
# 0    4429
# 1    1106
# Name: treatment_pd, dtype: int64
# 0    12685
# 1     9454
# Name: treatment_pd, dtype: int64
# 0    3171
# 1    2364
# Name: treatment_pd, dtype: int64
# 1    13549
# 0     8590
# Name: treatment_pd, dtype: int64
# 1    3387
# 0    2148
# Name: treatment_pd, dtype: int64

# %% [markdown]
# # Non-Imputed - LightGBM

# %% [markdown]
# <h4>Non-imputed 30-day classification</h4>

# %%
# Create the LightGBM dataset
train_nonimpute_data_30 = lgb.Dataset(X_train_nonimpute_30, label=y_train_30, feature_name='auto', categorical_feature=categorical_features)
test_nonimpute_data_30 = lgb.Dataset(X_test_nonimpute_30, label=y_test_30, feature_name='auto', categorical_feature=categorical_features)

# Define the hyperparameters for a classification model
params = {
    'objective': ['binary'],
    'metric': ['auc'], 
    'is_unbalance': [True],
    'boosting_type': ['dart'], 
    'n_estimators': [50, 100],
    'num_leaves': [31, 63],
    'learning_rate': [0.05, 0.1],
    'colsample_bytree': [0.9],
    'subsample': [0.9],
    'subsample_freq': [10],
    'verbose': [-1],
}

# Train the model
model_nonimpute_30 = lgb.LGBMClassifier()

# Create the grid search
grid_nonimpute_30 = GridSearchCV(model_nonimpute_30, params, cv=10, scoring='roc_auc')

# Fit the model to the data
grid_nonimpute_30.fit(X_train_nonimpute_30, y_train_30)
# Out:
# GridSearchCV(cv=10, estimator=LGBMClassifier(),
#              param_grid={'boosting_type': ['dart'], 'colsample_bytree': [0.9],
#                          'is_unbalance': [True], 'learning_rate': [0.05, 0.1],
#                          'metric': ['auc'], 'n_estimators': [50, 100],
#                          'num_leaves': [31, 63], 'objective': ['binary'],
#                          'subsample': [0.9], 'subsample_freq': [10],
#                          'verbose': [-1]},
#              scoring='roc_auc')

# %%
# Print best parameters
print('Best parameters:', grid_nonimpute_30.best_params_)

# Print best in-sample score
print('Insample AUC:', grid_nonimpute_30.best_score_)

# Test the model
y_test_pred_nonimpute_lgb_30 = grid_nonimpute_30.predict_proba(X_test_nonimpute_30)[:,1]

# Calculate AUC
fpr, tpr, thresholds = roc_curve(y_test_30, y_test_pred_nonimpute_lgb_30)

# Print AUC
print('AUC:', auc(fpr, tpr))
# Out:
# Best parameters: {'boosting_type': 'dart', 'colsample_bytree': 0.9, 'is_unbalance': True, 'learning_rate': 0.05, 'metric': 'auc', 'n_estimators': 50, 'num_leaves': 31, 'objective': 'binary', 'subsample': 0.9, 'subsample_freq': 10, 'verbose': -1}
# Insample AUC: 0.7014288752157013
# AUC: 0.7092010695575806

# %% [markdown]
# <h4>Non-imputed 60-day classification</h4>

# %%
# Create the LightGBM dataset
train_nonimpute_data_60 = lgb.Dataset(X_train_nonimpute_60, label=y_train_60, feature_name='auto', categorical_feature=categorical_features)
test_nonimpute_data_60 = lgb.Dataset(X_test_nonimpute_60, label=y_test_60, feature_name='auto', categorical_feature=categorical_features)

# Define the hyperparameters for a classification model
params = {
    'objective': ['binary'],
    'metric': ['auc'], 
    'is_unbalance': [True],
    'boosting_type': ['dart'], 
    'n_estimators': [50, 100],
    'num_leaves': [31, 63],
    'learning_rate': [0.05, 0.1],
    'colsample_bytree': [0.9],
    'subsample': [0.9],
    'subsample_freq': [10],
    'verbose': [-1],
}

# Train the model
model_nonimpute_60 = lgb.LGBMClassifier()

# Create the grid search
grid_nonimpute_60 = GridSearchCV(model_nonimpute_60, params, cv=10, scoring='roc_auc')

# Fit the model to the data
grid_nonimpute_60.fit(X_train_nonimpute_60, y_train_60)
# Out:
# GridSearchCV(cv=10, estimator=LGBMClassifier(),
#              param_grid={'boosting_type': ['dart'], 'colsample_bytree': [0.9],
#                          'is_unbalance': [True], 'learning_rate': [0.05, 0.1],
#                          'metric': ['auc'], 'n_estimators': [50, 100],
#                          'num_leaves': [31, 63], 'objective': ['binary'],
#                          'subsample': [0.9], 'subsample_freq': [10],
#                          'verbose': [-1]},
#              scoring='roc_auc')

# %%
# Print best parameters
print('Best parameters:', grid_nonimpute_60.best_params_)

# Print best in-sample score
print('Insample AUC:', grid_nonimpute_60.best_score_)

# Test the model
y_test_pred_nonimpute_lgb_60 = grid_nonimpute_60.predict_proba(X_test_nonimpute_60)[:,1]

# Calculate AUC
fpr, tpr, thresholds = roc_curve(y_test_60, y_test_pred_nonimpute_lgb_60)

# Print AUC
print('AUC:', auc(fpr, tpr))
# Out:
# Best parameters: {'boosting_type': 'dart', 'colsample_bytree': 0.9, 'is_unbalance': True, 'learning_rate': 0.1, 'metric': 'auc', 'n_estimators': 50, 'num_leaves': 31, 'objective': 'binary', 'subsample': 0.9, 'subsample_freq': 10, 'verbose': -1}
# Insample AUC: 0.724464975601192
# AUC: 0.7238690469520469

# %% [markdown]
# <h4>Non-imputed 90-day classification</h4>

# %%
# Create the LightGBM dataset
train_nonimpute_data_90 = lgb.Dataset(X_train_nonimpute_90, label=y_train_90, feature_name='auto', categorical_feature=categorical_features)
test_nonimpute_data_90 = lgb.Dataset(X_test_nonimpute_90, label=y_test_90, feature_name='auto', categorical_feature=categorical_features)

# Define the hyperparameters for a classification model
params = {
    'objective': ['binary'],
    'metric': ['auc'], 
    'is_unbalance': [True],
    'boosting_type': ['dart'], 
    'n_estimators': [50, 100],
    'num_leaves': [31, 63],
    'learning_rate': [0.05, 0.1],
    'colsample_bytree': [0.9],
    'subsample': [0.9],
    'subsample_freq': [10],
    'verbose': [-1],
}

# Train the model
model_nonimpute_90 = lgb.LGBMClassifier()

# Create the grid search
grid_nonimpute_90 = GridSearchCV(model_nonimpute_90, params, cv=10, scoring='roc_auc')

# Fit the model to the data
grid_nonimpute_90.fit(X_train_nonimpute_90, y_train_90)
# Out:
# GridSearchCV(cv=10, estimator=LGBMClassifier(),
#              param_grid={'boosting_type': ['dart'], 'colsample_bytree': [0.9],
#                          'is_unbalance': [True], 'learning_rate': [0.05, 0.1],
#                          'metric': ['auc'], 'n_estimators': [50, 100],
#                          'num_leaves': [31, 63], 'objective': ['binary'],
#                          'subsample': [0.9], 'subsample_freq': [10],
#                          'verbose': [-1]},
#              scoring='roc_auc')

# %%
# Print best parameters
print('Best parameters:', grid_nonimpute_90.best_params_)

# Print best in-sample score
print('Insample AUC:', grid_nonimpute_90.best_score_)

# Test the model
y_test_pred_nonimpute_lgb_90 = grid_nonimpute_90.predict_proba(X_test_nonimpute_90)[:,1]

# Calculate AUC
fpr, tpr, thresholds = roc_curve(y_test_90, y_test_pred_nonimpute_lgb_90)

# Print AUC
print('AUC:', auc(fpr, tpr))
# Out:
# Best parameters: {'boosting_type': 'dart', 'colsample_bytree': 0.9, 'is_unbalance': True, 'learning_rate': 0.1, 'metric': 'auc', 'n_estimators': 100, 'num_leaves': 31, 'objective': 'binary', 'subsample': 0.9, 'subsample_freq': 10, 'verbose': -1}
# Insample AUC: 0.764468057788723
# AUC: 0.7722348265550337

# %% [markdown]
# # Imputed - LightGBM

# %% [markdown]
# <h4>Imputed 30-day classification</h4>

# %%
# Create the LightGBM dataset
train_data_30 = lgb.Dataset(X_train_impute_30, label=y_train_30, feature_name='auto', categorical_feature=categorical_features)
test_data_30 = lgb.Dataset(X_test_impute_30, label=y_test_30, feature_name='auto', categorical_feature=categorical_features)

# Define the hyperparameters for a classification model
params = {
    'objective': ['binary'],
    'metric': ['auc'], 
    'is_unbalance': [True],
    'boosting_type': ['dart'], 
    'n_estimators': [50, 100],
    'num_leaves': [31, 63],
    'learning_rate': [0.05, 0.1],
    'colsample_bytree': [0.9],
    'subsample': [0.9],
    'subsample_freq': [10],
    'verbose': [-1],
}

# Train the model
model_impute_30 = lgb.LGBMClassifier()

# Create the grid search
grid_impute_30 = GridSearchCV(model_impute_30, params, cv=10, scoring='roc_auc')

# Fit the model to the data
grid_impute_30.fit(X_train_impute_30, y_train_30)
# Out:
# GridSearchCV(cv=10, estimator=LGBMClassifier(),
#              param_grid={'boosting_type': ['dart'], 'colsample_bytree': [0.9],
#                          'is_unbalance': [True], 'learning_rate': [0.05, 0.1],
#                          'metric': ['auc'], 'n_estimators': [50, 100],
#                          'num_leaves': [31, 63], 'objective': ['binary'],
#                          'subsample': [0.9], 'subsample_freq': [10],
#                          'verbose': [-1]},
#              scoring='roc_auc')

# %%
# Print best parameters
print('Best parameters:', grid_impute_30.best_params_)

# Print best in-sample score
print('Insample AUC:', grid_impute_30.best_score_)

# Test the model
y_test_pred_impute_lgb_30 = grid_impute_30.predict_proba(X_test_impute_30)[:,1]

# Calculate AUC
fpr, tpr, thresholds = roc_curve(y_test_30, y_test_pred_impute_lgb_30)

# Print AUC
print('AUC:', auc(fpr, tpr))
# Out:
# Best parameters: {'boosting_type': 'dart', 'colsample_bytree': 0.9, 'is_unbalance': True, 'learning_rate': 0.05, 'metric': 'auc', 'n_estimators': 50, 'num_leaves': 31, 'objective': 'binary', 'subsample': 0.9, 'subsample_freq': 10, 'verbose': -1}
# Insample AUC: 0.7001098101655292
# AUC: 0.7138134243439896

# %% [markdown]
# <h4>Imputed 60-day classification</h4>

# %%
# Create the LightGBM dataset
train_data_60 = lgb.Dataset(X_train_impute_60, label=y_train_60, feature_name='auto', categorical_feature=categorical_features)
test_data_60 = lgb.Dataset(X_test_impute_60, label=y_test_60, feature_name='auto', categorical_feature=categorical_features)

# Define the hyperparameters for a classification model
params = {
    'objective': ['binary'],
    'metric': ['auc'], 
    'is_unbalance': [True],
    'boosting_type': ['dart'], 
    'n_estimators': [50, 100],
    'num_leaves': [31, 63],
    'learning_rate': [0.05, 0.1],
    'colsample_bytree': [0.9],
    'subsample': [0.9],
    'subsample_freq': [10],
    'verbose': [-1],
}

# Train the model
model_impute_60 = lgb.LGBMClassifier()

# Create the grid search
grid_impute_60 = GridSearchCV(model_impute_60, params, cv=10, scoring='roc_auc')

# Fit the model to the data
grid_impute_60.fit(X_train_impute_60, y_train_60)
# Out:
# GridSearchCV(cv=10, estimator=LGBMClassifier(),
#              param_grid={'boosting_type': ['dart'], 'colsample_bytree': [0.9],
#                          'is_unbalance': [True], 'learning_rate': [0.05, 0.1],
#                          'metric': ['auc'], 'n_estimators': [50, 100],
#                          'num_leaves': [31, 63], 'objective': ['binary'],
#                          'subsample': [0.9], 'subsample_freq': [10],
#                          'verbose': [-1]},
#              scoring='roc_auc')

# %%
# Print best parameters
print('Best parameters:', grid_impute_60.best_params_)

# Print best score
print('Insample AUC:', grid_impute_60.best_score_)

# Test the model
y_test_pred_impute_lgb_60 = grid_impute_60.predict_proba(X_test_impute_60)[:,1]

# Calculate AUC
fpr, tpr, thresholds = roc_curve(y_test_60, y_test_pred_impute_lgb_60)

# Print AUC
print('AUC:', auc(fpr, tpr))
# Out:
# Best parameters: {'boosting_type': 'dart', 'colsample_bytree': 0.9, 'is_unbalance': True, 'learning_rate': 0.05, 'metric': 'auc', 'n_estimators': 100, 'num_leaves': 31, 'objective': 'binary', 'subsample': 0.9, 'subsample_freq': 10, 'verbose': -1}
# Insample AUC: 0.7238419066035159
# AUC: 0.7239783016668081

# %% [markdown]
# <h4>Imputed 90-day classification</h4>

# %%
# Create the LightGBM dataset
train_data_90 = lgb.Dataset(X_train_impute_90, label=y_train_90, feature_name='auto', categorical_feature=categorical_features)
test_data_90 = lgb.Dataset(X_test_impute_90, label=y_test_90, feature_name='auto', categorical_feature=categorical_features)

# Define the hyperparameters for a classification model
params = {
    'objective': ['binary'],
    'metric': ['auc'], 
    'is_unbalance': [True],
    'boosting_type': ['dart'], 
    'n_estimators': [50, 100],
    'num_leaves': [31, 63],
    'learning_rate': [0.05, 0.1],
    'colsample_bytree': [0.9],
    'subsample': [0.9],
    'subsample_freq': [10],
    'verbose': [-1],
}

# Train the model
model_impute_90 = lgb.LGBMClassifier()

# Create the grid search
grid_impute_90 = GridSearchCV(model_impute_90, params, cv=10, scoring='roc_auc')

# Fit the model to the data
grid_impute_90.fit(X_train_impute_90, y_train_90)
# Out:
# GridSearchCV(cv=10, estimator=LGBMClassifier(),
#              param_grid={'boosting_type': ['dart'], 'colsample_bytree': [0.9],
#                          'is_unbalance': [True], 'learning_rate': [0.05, 0.1],
#                          'metric': ['auc'], 'n_estimators': [50, 100],
#                          'num_leaves': [31, 63], 'objective': ['binary'],
#                          'subsample': [0.9], 'subsample_freq': [10],
#                          'verbose': [-1]},
#              scoring='roc_auc')

# %%
# Print best parameters
print('Best parameters:', grid_impute_90.best_params_)

# Print best score
print('Best score:', grid_impute_90.best_score_)

# Test the model
y_test_pred_impute_lgb_90 = grid_impute_90.predict_proba(X_test_impute_90)[:,1]

# Calculate AUC
fpr, tpr, thresholds = roc_curve(y_test_90, y_test_pred_impute_lgb_90)

# Print AUC
print('AUC:', auc(fpr, tpr))
# Out:
# Best parameters: {'boosting_type': 'dart', 'colsample_bytree': 0.9, 'is_unbalance': True, 'learning_rate': 0.1, 'metric': 'auc', 'n_estimators': 100, 'num_leaves': 31, 'objective': 'binary', 'subsample': 0.9, 'subsample_freq': 10, 'verbose': -1}
# Best score: 0.7634485049136333
# AUC: 0.770795087361634

# %% [markdown]
# ## Imputed - Lasso/Logistic Reg/Random Forest

# %%
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score

# %%
# Note: Looks like we need to on-hot-encode categorical features for RandomForestRegressor to work
# 30-day train/test sets
onehot_feat_train_impute_30 = pd.get_dummies(X_train_impute_30, dummy_na = False)
onehot_feat_test_impute_30 = pd.get_dummies(X_test_impute_30, dummy_na = False)

# 60-day train/test sets
onehot_feat_train_impute_60 = pd.get_dummies(X_train_impute_60, dummy_na = False)
onehot_feat_test_impute_60 = pd.get_dummies(X_test_impute_60, dummy_na = False)

# 90-day train/test sets
onehot_feat_train_impute_90 = pd.get_dummies(X_train_impute_90, dummy_na = False)
onehot_feat_test_impute_90 = pd.get_dummies(X_test_impute_90, dummy_na = False)

# %% [markdown]
# <h4>Random Forest 30-days classification</h4>

# %%
rand_forest_30 = RandomForestClassifier()

# Fit the model to the data
rand_forest_30.fit(onehot_feat_train_impute_30, y_train_30.values.ravel())

# Test the model
y_test_pred_impute_rf_30 = rand_forest_30.predict_proba(onehot_feat_test_impute_30)[:, 1]

# Print AUROC
print('AUROC:', roc_auc_score(y_true=y_test_30, y_score=y_test_pred_impute_rf_30))
# Out:
# AUROC: 0.6257371173144943

# %% [markdown]
# <h4>Random Forest 60-days classification</h4>

# %%
rand_forest_60 = RandomForestClassifier()

# Fit the model to the data
rand_forest_60.fit(onehot_feat_train_impute_60, y_train_60.values.ravel())

# Test the model
y_test_pred_impute_rf_60 = rand_forest_60.predict_proba(onehot_feat_test_impute_60)[:, 1]

# Print AUROC
print('AUROC:', roc_auc_score(y_true=y_test_60, y_score=y_test_pred_impute_rf_60))
# Out:
# AUROC: 0.6686636667643155

# %% [markdown]
# <h4>Random Forest 90-days classification</h4>

# %%
rand_forest_90 = RandomForestClassifier()

# Fit the model to the data
rand_forest_90.fit(onehot_feat_train_impute_90, y_train_90.values.ravel())

# Test the model
y_test_pred_impute_rf_90 = rand_forest_90.predict_proba(onehot_feat_test_impute_90)[:, 1]

# Print AUROC
print('AUROC:', roc_auc_score(y_true=y_test_90, y_score=y_test_pred_impute_rf_90))
# Out:
# AUROC: 0.7289099410111726

# %% [markdown]
# <h4>Logistic Regression 30-day classification</h4>

# %%
log_reg_30 = LogisticRegression(solver='liblinear')

# Fit the model to the data
log_reg_30.fit(onehot_feat_train_impute_30, y_train_30.values.ravel())

# Test the model
y_test_pred_impute_log_reg_30 = log_reg_30.predict_proba(onehot_feat_test_impute_30)[:, 1]

# Print AUROC
print('30-day AUROC:', roc_auc_score(y_true=y_test_30, y_score=y_test_pred_impute_log_reg_30))
# Out:
# 30-day AUROC: 0.5683500616722678

# %% [markdown]
# <h4>Logistic Regression 60-day classification</h4>

# %%
log_reg_60 = LogisticRegression(solver='liblinear')

# Fit the model to the data
log_reg_60.fit(onehot_feat_train_impute_60, y_train_60.values.ravel())

# Test the model
y_test_pred_impute_log_reg_60 = log_reg_60.predict_proba(onehot_feat_test_impute_60)[:, 1]

# Print AUROC
print('60-day AUROC:', roc_auc_score(y_true=y_test_60, y_score=y_test_pred_impute_log_reg_60))
# Out:
# 60-day AUROC: 0.5477308369364711

# %% [markdown]
# <h4>Logistic Regression 90-day classification</h4>

# %%
log_reg_90 = LogisticRegression(solver='liblinear')

# Fit the model to the data
log_reg_90.fit(onehot_feat_train_impute_90, y_train_90.values.ravel())

# Test the model
y_test_pred_impute_log_reg_90 = log_reg_90.predict_proba(onehot_feat_test_impute_90)[:, 1]

# Pring ROC AUC 
print('90-day AUROC:', roc_auc_score(y_true=y_test_90, y_score=y_test_pred_impute_log_reg_90))
# Out:
# 90-day AUROC: 0.5276550332935823

# %% [markdown]
# <h4>LASSO 30-day classification</h4>

# %%
l1_30 = LogisticRegression(penalty='l1', solver='liblinear')

# Fit the model to the data
l1_30.fit(onehot_feat_train_impute_30, y_train_30.values.ravel())

# Test the model
y_test_pred_impute_l1_30 = l1_30.predict_proba(onehot_feat_test_impute_30)[:, 1]

# Print AUROC
print('30-day AUROC:', roc_auc_score(y_true=y_test_30, y_score=y_test_pred_impute_l1_30))
# Out:
# 30-day AUROC: 0.699188767767268

# %% [markdown]
# <h4>LASSO 60-day classification</h4>

# %%
l1_60 = LogisticRegression(penalty='l1', solver='liblinear')

# Fit the model to the data
l1_60.fit(onehot_feat_train_impute_60, y_train_60.values.ravel())

# Test the model
y_test_pred_impute_l1_60 = l1_60.predict_proba(onehot_feat_test_impute_60)[:, 1]

# Print AUROC
print('60-day AUROC:', roc_auc_score(y_true=y_test_60, y_score=y_test_pred_impute_l1_60))
# Out:
# 60-day AUROC: 0.7126176789336098

# %% [markdown]
# <h4>LASSO 90-day classification</h4>

# %%
l1_90 = LogisticRegression(penalty='l1', solver='liblinear')

# Fit the model to the data
l1_90.fit(onehot_feat_train_impute_90, y_train_90.values.ravel())

# Test the model
y_test_pred_impute_l1_90 = l1_90.predict_proba(onehot_feat_test_impute_90)[:, 1]

# Print AUROC
print('90-day AUROC:', roc_auc_score(y_true=y_test_90, y_score=y_test_pred_impute_l1_90))
# Out:
# 90-day AUROC: 0.7654215455193727

# %% [markdown]
# # SHAP Values

# %%
import shap
shap.initjs()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %% [markdown]
# <h4>Non-imputed LightGBM</h4>

# %%
# Calculate shapley values for non-imputed lightGBM
explainer = shap.TreeExplainer(grid_nonimpute_30.best_estimator_)
shap_values = explainer.shap_values(X_test_nonimpute_30)
shap.summary_plot(shap_values[1], X_test_nonimpute_30, plot_type='bar')

# %% [markdown]
# <h4>Sensitivity analysis - Lasso imputed</h4>

# %%
# Use KernelExplainer for models that are not tree-based
# Define a function that outputs the prediction probabilities
f = lambda x: l1_30.predict_proba(x)[:, 1]

# Initialize explainer object
explainer = shap.KernelExplainer(f, shap.kmeans(onehot_feat_train_impute_30, 10))

# Compute SHAP values
shap_values = explainer.shap_values(onehot_feat_test_impute_30)

# Plot the summary plot
shap.summary_plot(shap_values, onehot_feat_test_impute_30, plot_type='bar')
# Out:
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 0/5535 [00:00<?, ?it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 1/5535 [00:00<28:28,  3.24it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 2/5535 [00:00<30:32,  3.02it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 3/5535 [00:00<30:04,  3.07it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 4/5535 [00:01<30:21,  3.04it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 5/5535 [00:01<28:44,  3.21it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 6/5535 [00:01<29:06,  3.17it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 7/5535 [00:02<24:53,  3.70it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 8/5535 [00:02<27:56,  3.30it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 9/5535 [00:02<33:00,  2.79it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 10/5535 [00:03<33:58,  2.71it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 11/5535 [00:03<32:45,  2.81it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 12/5535 [00:03<29:13,  3.15it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 13/5535 [00:04<29:49,  3.09it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 14/5535 [00:04<31:03,  2.96it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 15/5535 [00:05<34:15,  2.69it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 16/5535 [00:05<34:17,  2.68it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 17/5535 [00:05<33:06,  2.78it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 18/5535 [00:06<37:00,  2.48it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 19/5535 [00:07<47:35,  1.93it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 20/5535 [00:07<50:57,  1.80it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 21/5535 [00:08<46:45,  1.97it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 22/5535 [00:08<39:37,  2.32it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 23/5535 [00:08<40:21,  2.28it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 24/5535 [00:09<37:18,  2.46it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 25/5535 [00:09<39:23,  2.33it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 26/5535 [00:09<36:42,  2.50it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   0%|          | 27/5535 [00:10<35:29,  2.59it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 28/5535 [00:10<32:50,  2.79it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 29/5535 [00:10<30:29,  3.01it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 30/5535 [00:11<27:24,  3.35it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 31/5535 [00:11<32:41,  2.81it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 32/5535 [00:11<29:26,  3.12it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 33/5535 [00:12<28:53,  3.17it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 34/5535 [00:12<29:10,  3.14it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 35/5535 [00:12<27:01,  3.39it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 36/5535 [00:12<25:48,  3.55it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 37/5535 [00:13<23:07,  3.96it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 38/5535 [00:13<24:01,  3.81it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 39/5535 [00:13<25:37,  3.58it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 40/5535 [00:14<28:14,  3.24it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 41/5535 [00:14<28:05,  3.26it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 42/5535 [00:14<27:13,  3.36it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 43/5535 [00:14<25:37,  3.57it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 44/5535 [00:15<28:13,  3.24it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 45/5535 [00:15<27:20,  3.35it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 46/5535 [00:15<27:42,  3.30it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 47/5535 [00:16<30:24,  3.01it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 48/5535 [00:16<30:47,  2.97it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 49/5535 [00:16<29:24,  3.11it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 50/5535 [00:17<38:24,  2.38it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 51/5535 [00:18<56:30,  1.62it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 52/5535 [00:19<50:46,  1.80it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 53/5535 [00:19<54:36,  1.67it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 54/5535 [00:20<54:26,  1.68it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 55/5535 [00:20<49:29,  1.85it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 56/5535 [00:21<55:42,  1.64it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 57/5535 [00:21<50:00,  1.83it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 58/5535 [00:22<44:19,  2.06it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 59/5535 [00:22<39:58,  2.28it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 60/5535 [00:23<39:18,  2.32it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 61/5535 [00:23<35:26,  2.57it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 62/5535 [00:23<40:13,  2.27it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 63/5535 [00:24<42:04,  2.17it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 64/5535 [00:24<42:53,  2.13it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 65/5535 [00:25<46:25,  1.96it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 66/5535 [00:26<51:17,  1.78it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 67/5535 [00:26<52:28,  1.74it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 68/5535 [00:27<45:42,  1.99it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|          | 69/5535 [00:27<47:25,  1.92it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|▏         | 70/5535 [00:27<41:33,  2.19it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|▏         | 71/5535 [00:28<37:10,  2.45it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|▏         | 72/5535 [00:28<38:45,  2.35it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|▏         | 73/5535 [00:29<35:36,  2.56it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|▏         | 74/5535 [00:29<33:12,  2.74it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|▏         | 75/5535 [00:29<34:09,  2.66it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|▏         | 76/5535 [00:30<33:39,  2.70it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|▏         | 77/5535 [00:30<32:18,  2.82it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|▏         | 78/5535 [00:30<27:46,  3.27it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|▏         | 79/5535 [00:30<27:31,  3.30it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|▏         | 80/5535 [00:31<25:43,  3.53it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|▏         | 81/5535 [00:31<25:13,  3.60it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|▏         | 82/5535 [00:31<24:32,  3.70it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   1%|▏         | 83/5535 [00:32<29:56,  3.03it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 84/5535 [00:32<28:38,  3.17it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 85/5535 [00:32<27:37,  3.29it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 86/5535 [00:33<30:30,  2.98it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 87/5535 [00:33<30:41,  2.96it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 88/5535 [00:33<27:42,  3.28it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 89/5535 [00:33<27:09,  3.34it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 90/5535 [00:34<28:13,  3.21it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 91/5535 [00:34<32:01,  2.83it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 92/5535 [00:35<30:01,  3.02it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 93/5535 [00:35<31:53,  2.84it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 94/5535 [00:35<30:08,  3.01it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 95/5535 [00:35<27:53,  3.25it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 96/5535 [00:36<28:58,  3.13it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 97/5535 [00:36<28:24,  3.19it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 98/5535 [00:36<28:05,  3.23it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 99/5535 [00:37<26:19,  3.44it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 100/5535 [00:37<28:06,  3.22it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 101/5535 [00:37<28:29,  3.18it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 102/5535 [00:38<26:37,  3.40it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 103/5535 [00:38<27:50,  3.25it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 104/5535 [00:38<27:30,  3.29it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 105/5535 [00:39<27:35,  3.28it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 106/5535 [00:39<27:35,  3.28it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 107/5535 [00:39<26:47,  3.38it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 108/5535 [00:39<25:06,  3.60it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 109/5535 [00:40<25:31,  3.54it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 110/5535 [00:40<23:35,  3.83it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 111/5535 [00:40<23:29,  3.85it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 112/5535 [00:40<27:29,  3.29it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 113/5535 [00:41<28:17,  3.19it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 114/5535 [00:41<29:02,  3.11it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 115/5535 [00:41<27:56,  3.23it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 116/5535 [00:42<28:57,  3.12it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 117/5535 [00:42<28:23,  3.18it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 118/5535 [00:42<28:49,  3.13it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 119/5535 [00:43<25:52,  3.49it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 120/5535 [00:43<28:24,  3.18it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 121/5535 [00:43<27:15,  3.31it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 122/5535 [00:44<30:50,  2.93it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 123/5535 [00:44<30:29,  2.96it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 124/5535 [00:44<28:13,  3.19it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 125/5535 [00:45<28:34,  3.16it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 126/5535 [00:45<29:42,  3.03it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 127/5535 [00:45<28:03,  3.21it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 128/5535 [00:46<28:29,  3.16it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 129/5535 [00:46<28:17,  3.19it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 130/5535 [00:46<28:38,  3.15it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 131/5535 [00:47<29:59,  3.00it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 132/5535 [00:47<29:37,  3.04it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 133/5535 [00:47<28:47,  3.13it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 134/5535 [00:47<27:16,  3.30it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 135/5535 [00:48<26:51,  3.35it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 136/5535 [00:48<28:03,  3.21it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 137/5535 [00:48<28:58,  3.10it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   2%|▏         | 138/5535 [00:49<30:50,  2.92it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 139/5535 [00:49<34:51,  2.58it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 140/5535 [00:50<36:11,  2.48it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 141/5535 [00:50<35:54,  2.50it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 142/5535 [00:51<38:19,  2.34it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 143/5535 [00:51<40:50,  2.20it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 144/5535 [00:52<37:29,  2.40it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 145/5535 [00:52<46:04,  1.95it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 146/5535 [00:53<53:02,  1.69it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 147/5535 [00:53<46:08,  1.95it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 148/5535 [00:54<41:12,  2.18it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 149/5535 [00:54<38:14,  2.35it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 150/5535 [00:55<39:51,  2.25it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 151/5535 [00:55<36:19,  2.47it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 152/5535 [00:55<38:51,  2.31it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 153/5535 [00:56<36:35,  2.45it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 154/5535 [00:56<34:42,  2.58it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 155/5535 [00:56<32:30,  2.76it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 156/5535 [00:57<30:50,  2.91it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 157/5535 [00:57<39:39,  2.26it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 158/5535 [00:58<37:30,  2.39it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 159/5535 [00:58<33:30,  2.67it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 160/5535 [00:58<31:19,  2.86it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 161/5535 [00:59<33:18,  2.69it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 162/5535 [00:59<45:50,  1.95it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 163/5535 [01:00<46:19,  1.93it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 164/5535 [01:01<49:50,  1.80it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 165/5535 [01:01<51:40,  1.73it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 166/5535 [01:02<52:08,  1.72it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 167/5535 [01:02<48:36,  1.84it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 168/5535 [01:03<42:43,  2.09it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 169/5535 [01:03<40:19,  2.22it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 170/5535 [01:03<34:54,  2.56it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 171/5535 [01:04<30:24,  2.94it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 172/5535 [01:04<29:39,  3.01it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 173/5535 [01:04<28:22,  3.15it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 174/5535 [01:04<26:49,  3.33it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 175/5535 [01:05<30:09,  2.96it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 176/5535 [01:05<35:52,  2.49it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 177/5535 [01:06<32:29,  2.75it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 178/5535 [01:06<38:15,  2.33it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 179/5535 [01:07<37:22,  2.39it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 180/5535 [01:07<38:49,  2.30it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 181/5535 [01:07<35:14,  2.53it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 182/5535 [01:08<38:01,  2.35it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 183/5535 [01:08<36:10,  2.47it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 184/5535 [01:09<35:32,  2.51it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 185/5535 [01:09<36:47,  2.42it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 186/5535 [01:10<48:12,  1.85it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 187/5535 [01:10<43:09,  2.07it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 188/5535 [01:11<44:35,  2.00it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 189/5535 [01:11<49:11,  1.81it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 190/5535 [01:12<46:00,  1.94it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 191/5535 [01:12<44:54,  1.98it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 192/5535 [01:13<44:40,  1.99it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   3%|▎         | 193/5535 [01:13<47:10,  1.89it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   4%|▎         | 194/5535 [01:14<45:04,  1.98it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   4%|▎         | 195/5535 [01:14<39:56,  2.23it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   4%|▎         | 196/5535 [01:15<38:11,  2.33it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   4%|▎         | 197/5535 [01:15<44:37,  1.99it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   4%|▎         | 198/5535 [01:16<39:27,  2.25it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   4%|▎         | 199/5535 [01:16<35:42,  2.49it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   4%|▎         | 200/5535 [01:16<40:31,  2.19it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   4%|▎         | 201/5535 [01:17<43:49,  2.03it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   4%|▎         | 202/5535 [01:17<41:42,  2.13it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   4%|▎         | 203/5535 [01:18<40:18,  2.20it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   4%|▎         | 204/5535 [01:18<37:28,  2.37it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   4%|▎         | 205/5535 [01:19<37:27,  2.37it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   4%|▎         | 206/5535 [01:19<33:46,  2.63it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#   4%|▎         | 207/5535 [01:19<30:02,  2.96it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# ...
#  99%|█████████▉| 5466/5535 [28:52<00:18,  3.74it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5467/5535 [28:52<00:17,  3.85it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5468/5535 [28:53<00:18,  3.61it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5469/5535 [28:53<00:18,  3.62it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5470/5535 [28:53<00:18,  3.59it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5471/5535 [28:54<00:18,  3.37it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5472/5535 [28:54<00:17,  3.66it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5473/5535 [28:54<00:16,  3.73it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5474/5535 [28:54<00:16,  3.79it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5475/5535 [28:55<00:16,  3.66it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5476/5535 [28:55<00:15,  3.92it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5477/5535 [28:55<00:14,  4.03it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5478/5535 [28:55<00:14,  3.93it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5479/5535 [28:56<00:16,  3.48it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5480/5535 [28:56<00:15,  3.59it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5481/5535 [28:56<00:15,  3.55it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5482/5535 [28:57<00:15,  3.33it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5483/5535 [28:57<00:15,  3.30it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5484/5535 [28:57<00:14,  3.46it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5485/5535 [28:57<00:13,  3.71it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5486/5535 [28:58<00:14,  3.46it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5487/5535 [28:58<00:13,  3.43it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5488/5535 [28:58<00:12,  3.70it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5489/5535 [28:59<00:13,  3.47it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5490/5535 [28:59<00:12,  3.66it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5491/5535 [28:59<00:13,  3.37it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5492/5535 [28:59<00:13,  3.18it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5493/5535 [29:00<00:13,  3.15it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5494/5535 [29:00<00:12,  3.40it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5495/5535 [29:00<00:10,  3.64it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5496/5535 [29:01<00:12,  3.24it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5497/5535 [29:01<00:10,  3.53it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5498/5535 [29:01<00:10,  3.45it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5499/5535 [29:01<00:10,  3.50it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5500/5535 [29:02<00:09,  3.73it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5501/5535 [29:02<00:09,  3.60it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5502/5535 [29:02<00:10,  3.26it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5503/5535 [29:03<00:10,  3.18it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5504/5535 [29:03<00:09,  3.33it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5505/5535 [29:03<00:10,  2.87it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5506/5535 [29:04<00:09,  3.05it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
#  99%|█████████▉| 5507/5535 [29:04<00:09,  3.09it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5508/5535 [29:04<00:08,  3.19it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5509/5535 [29:05<00:07,  3.32it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5510/5535 [29:05<00:07,  3.49it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5511/5535 [29:05<00:06,  3.49it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5512/5535 [29:05<00:06,  3.45it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5513/5535 [29:06<00:05,  3.71it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5514/5535 [29:06<00:05,  3.78it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5515/5535 [29:06<00:05,  3.64it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5516/5535 [29:06<00:05,  3.69it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5517/5535 [29:07<00:05,  3.27it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5518/5535 [29:07<00:05,  3.26it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5519/5535 [29:07<00:04,  3.39it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5520/5535 [29:08<00:04,  3.30it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5521/5535 [29:08<00:03,  3.56it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5522/5535 [29:08<00:03,  3.78it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5523/5535 [29:09<00:03,  3.45it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5524/5535 [29:09<00:03,  3.64it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5525/5535 [29:09<00:02,  3.56it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5526/5535 [29:09<00:02,  3.39it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5527/5535 [29:10<00:02,  3.24it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5528/5535 [29:10<00:02,  3.22it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5529/5535 [29:10<00:01,  3.42it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5530/5535 [29:11<00:01,  3.14it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5531/5535 [29:11<00:01,  2.92it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5532/5535 [29:11<00:00,  3.30it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5533/5535 [29:12<00:00,  3.47it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|█████████▉| 5534/5535 [29:12<00:00,  3.34it/s]X does not have valid feature names, but LogisticRegression was fitted with feature names
# X does not have valid feature names, but LogisticRegression was fitted with feature names
# 100%|██████████| 5535/5535 [29:12<00:00,  3.16it/s]

# %% [markdown]
# # Write output files for all models

# %%
# Write output of all models and labels to CSV

## Training data - imputed
X_train_impute_30['Y_truth_30'] = y_train_30
X_train_impute_60['Y_tuth_60'] = y_train_60
X_train_impute_90['Y_truth_90'] = y_train_90

X_train_impute_30.to_csv('../Output/train_impute_30.csv', index=False)
X_train_impute_60.to_csv('../Output/train_impute_60.csv', index=False)
X_train_impute_90.to_csv('../Output/train_impute_90.csv', index=False)

## Test data - imputed 30 day
X_test_impute_30['Y_truth_30'] = y_test_30
X_test_impute_30['y_pred_30_lgb'] = y_test_pred_impute_lgb_30
X_test_impute_30['y_pred_30_rf'] = y_test_pred_impute_rf_30
X_test_impute_30['y_pred_30_log_reg'] = y_test_pred_impute_log_reg_30
X_test_impute_30['y_pred_30_l1'] = y_test_pred_impute_l1_30

## Test data - imputed 60 day
X_test_impute_60['Y_truth_60'] = y_test_60
X_test_impute_60['y_pred_60_lgb'] = y_test_pred_impute_lgb_60
X_test_impute_60['y_pred_60_rf'] = y_test_pred_impute_rf_60
X_test_impute_60['y_pred_60_log_reg'] = y_test_pred_impute_log_reg_60
X_test_impute_60['y_pred_60_l1'] = y_test_pred_impute_l1_60

## Test data - imputed 90 day
X_test_impute_90['Y_truth_90'] = y_test_90
X_test_impute_90['y_pred_90_lgb'] = y_test_pred_impute_lgb_90
X_test_impute_90['y_pred_90_rf'] = y_test_pred_impute_rf_90
X_test_impute_90['y_pred_90_log_reg'] = y_test_pred_impute_log_reg_90
X_test_impute_90['y_pred_90_l1'] = y_test_pred_impute_l1_90

X_test_impute_30.to_csv('../Output/test_impute_30.csv', index=False)
X_test_impute_60.to_csv('../Output/test_impute_60.csv', index=False)
X_test_impute_90.to_csv('../Output/test_impute_90.csv', index=False)
